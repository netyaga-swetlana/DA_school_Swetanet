# %% [markdown]
# # <a id='1'>Обзоры на приложения в Google Play Store</a>
#
# https://www.kaggle.com/gauthamp10/google-playstore-apps
#
# 1. Подготовьте список самых популярных приложений по категориям
# 2. Какие приложения самые дорогие (и категории)
# 3. Какие категории содержат самое большое количество приложений без отзывов

# %% [markdown]
# # Загрузка пакетов

# %%
import gc
import os
import logging
import datetime
import warnings
import pandas as pd
import seaborn as sns
from datetime import date
import numpy as np 
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# #####  Загрузка данных

# %%
IS_LOCAL = False
if(IS_LOCAL):
    PATH="https://www.kaggle.com/gauthamp10/google-playstore-apps"
else:
    PATH="data"
os.listdir(PATH)
# Out:
# ['Google-Playstore.csv']

# %%
# %%time
apps = pd.read_csv('data/Google-Playstore.csv')
# Out:
# Wall time: 14.1 s

# %% [markdown]
# ### <a id='2'>АНАЛИЗ ДАННЫХ</a>

# %% [markdown]
# ## <a id='31'>Проверяем данные</a>

# %%
apps.shape
# Out:
# (2312944, 24)

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# dtypes: bool(4), float64(4), int64(1), object(15)
# memory usage: 361.8+ MB

# %%
apps.describe()
# Out:
#              Rating  Rating Count  Minimum Installs  Maximum Installs  \
# count  2.290061e+06  2.290061e+06      2.312837e+06      2.312944e+06
# mean   2.203152e+00  2.864839e+03      1.834452e+05      3.202017e+05
# std    2.106223e+00  2.121626e+05      1.513144e+07      2.355495e+07
# min    0.000000e+00  0.000000e+00      0.000000e+00      0.000000e+00
# 25%    0.000000e+00  0.000000e+00      5.000000e+01      8.400000e+01
# 50%    2.900000e+00  6.000000e+00      5.000000e+02      6.950000e+02
# 75%    4.300000e+00  4.200000e+01      5.000000e+03      7.354000e+03
# max    5.000000e+00  1.385576e+08      1.000000e+10      1.205763e+10
#
#               Price
# count  2.312944e+06
# mean   1.034992e-01
# std    2.633127e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    4.000000e+02

# %%
apps.describe(include='O')
# Out:
#            App Name                   App Id   Category Installs Currency  \
# count       2312942                  2312944    2312944  2312837  2312809
# unique      2177944                  2312944         48       22       15
# top     Tic Tac Toe  com.amend.universoamend  Education     100+      USD
# freq            382                        1     241090   443368  2311548
#
#                       Size Minimum Android   Developer Id  \
# count              2312748         2306414        2312911
# unique                1657             154         758371
# top     Varies with device      4.1 and up  Subsplash Inc
# freq                 74777          604465           5422
#
#                 Developer Website       Developer Email      Released  \
# count                     1552109               2312913       2241891
# unique                     810440                950456          4158
# top     http://www.subsplash.com/  support@classplus.co  Jun 16, 2020
# freq                         7519                 10345          2051
#
#         Last Updated Content Rating                          Privacy Policy  \
# count        2312944        2312944                                 1891991
# unique          3918              6                                  977743
# top     Jun 10, 2021       Everyone  http://www.subsplash.com/legal/privacy
# freq           11186        2022089                                    7481
#
#                Scraped Time
# count               2312944
# unique                67374
# top     2021-06-16 07:35:57
# freq                     56

# %%
apps.head(10)
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
# 5                                             IMOCCI
# 6                   unlimited 4G data prank free app
# 7                              The Everyday Calendar
# 8                                          WhatsOpen
# 9                   Neon 3d Iron Tech Keyboard Theme
#
#                                           App Id          Category  Rating  \
# 0                            com.ishakwe.gakondo         Adventure     0.0
# 1                     com.webserveis.batteryinfo             Tools     4.4
# 2                           com.doantiepvien.crm      Productivity     0.0
# 3                        cst.stJoseph.ug17ucs548     Communication     5.0
# 4                           com.horodyski.grower             Tools     0.0
# 5                                     com.imocci            Social     0.0
# 6  getfreedata.superfatiza.unlimitedjiodataprank  Libraries & Demo     4.5
# 7                         com.mozaix.simoneboard         Lifestyle     2.0
# 8                              com.whatsopen.app     Communication     0.0
# 9          com.ikeyboard.theme.neon_3d.iron.tech   Personalization     4.7
#
#    Rating Count Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0           0.0      10+              10.0                15  True    0.0
# 1          64.0   5,000+            5000.0              7662  True    0.0
# 2           0.0      50+              50.0                58  True    0.0
# 3           5.0      10+              10.0                19  True    0.0
# 4           0.0     100+             100.0               478  True    0.0
# 5           0.0      50+              50.0                89  True    0.0
# 6          12.0   1,000+            1000.0              2567  True    0.0
# 7          39.0     500+             500.0               702  True    0.0
# 8           0.0      10+              10.0                18  True    0.0
# 9         820.0  50,000+           50000.0             62433  True    0.0
#
#    ...                    Developer Website                  Developer Email  \
# 0  ...          https://beniyizibyose.tk/#/           jean21101999@gmail.com
# 1  ...      https://webserveis.netlify.app/             webserveis@gmail.com
# 2  ...                                  NaN              vnacrewit@gmail.com
# 3  ...     http://www.climatesmarttech.com/      climatesmarttech2@gmail.com
# 4  ...          http://www.horodyski.com.pl        rmilekhorodyski@gmail.com
# 5  ...                http://www.imocci.com                  info@imocci.com
# 6  ...                                  NaN  aitomgharfatimezzahra@gmail.com
# 7  ...                                  NaN          elementuser03@gmail.com
# 8  ...             http://yilvermolinah.com          yilver.mh1996@gmail.com
# 9  ...  https://trendyteme888-31139.web.app         trendyteme.888@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone
# 1  May 21, 2020  May 06, 2021       Everyone
# 2   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  Sep 10, 2018  Oct 13, 2018       Everyone
# 4  Feb 21, 2020  Nov 12, 2018       Everyone
# 5  Dec 24, 2018  Dec 20, 2019           Teen
# 6  Sep 23, 2019  Sep 27, 2019       Everyone
# 7  Jun 21, 2019  Jun 21, 2019       Everyone
# 8           NaN  Dec 07, 2018           Teen
# 9  Sep 22, 2019  Oct 07, 2020       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
# 5  https://www.imocci.com/wp-content/uploads/2018...        False
# 6  https://sites.google.com/view/unlimited4gdatap...         True
# 7  https://www.freeprivacypolicy.com/privacy/view...        False
# 8  http://elcafedelamanana.yilvermolinah.com/poli...        False
# 9                        http://bit.ly/EmojiThemePro         True
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 20:19:35
# 1            False          False  2021-06-15 20:19:35
# 2            False          False  2021-06-15 20:19:35
# 3            False          False  2021-06-15 20:19:35
# 4            False          False  2021-06-15 20:19:35
# 5             True          False  2021-06-15 20:19:35
# 6            False          False  2021-06-15 20:19:35
# 7            False          False  2021-06-15 20:19:35
# 8            False          False  2021-06-15 20:19:35
# 9            False          False  2021-06-15 20:19:35
#
# [10 rows x 24 columns]

# %% [markdown]
# ### Данные представляют собой таблицу в 24 столбца и 2312944 строк- приложения Google:
#                         App Name         Имя приложения
#                         App Id   Идентификатор приложения
#                         Category  Категория
#                         Rating  Оценка
#                         Rating Count  Количество Рейтингов
#                         Installs   Установка
#                         Minimum Installs  Минимальные Установки
#                         Maximum Installs  Максимальная Установка
#                         Free   Бесплатно
#                         Price   Цена
#                         Currency  Валюта
#                         Size   Размер
#                         Minimum Android   Минимум Android
#                         Developer Id    Идентификатор разработчика
#                         Developer Website    Сайт разработчика
#                         Developer Email   Электронная почта разработчика
#                         Released   Выпущенный
#                         Privacy Policy   Политика конфиденциальности
#                         Last Updated   Последнее обновление
#                         Content Rating   Рейтинг Контента
#                         Ad Supported   Поддержка рекламы
#                         In app purchases   Покупки в приложении
#                         Editor Choice    Выбор редактора
#                         Scraped Time   Собранное время

# %%
# Графики распределения данных столбцов
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 100]] #Отображаем только столбцы, имеющие менее 100 уникальных значений   
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.show()

# %%
plotPerColumnDistribution(apps, 24, 3)

# %%
apps1=apps[(apps["Rating Count"]==apps["Rating Count"].max())]
apps1
# Out:
#                   App Name        App Id       Category  Rating  Rating Count  \
# 385470  WhatsApp Messenger  com.whatsapp  Communication     4.0   138557570.0
#
#               Installs  Minimum Installs  Maximum Installs  Free  Price  ...  \
# 385470  5,000,000,000+      5.000000e+09        6265637751  True    0.0  ...
#
#                Developer Website               Developer Email      Released  \
# 385470  http://www.whatsapp.com/  android@support.whatsapp.com  Oct 18, 2010
#
#         Last Updated Content Rating                          Privacy Policy  \
# 385470  Jun 09, 2021       Everyone  http://www.whatsapp.com/legal/#Privacy
#
#        Ad Supported In App Purchases Editors Choice         Scraped Time
# 385470        False            False           True  2021-06-16 02:51:24
#
# [1 rows x 24 columns]

# %%
apps2=apps[(apps["Maximum Installs"]==apps["Maximum Installs"].max())]
apps2
# Out:
#                      App Name                  App Id Category  Rating  \
# 2155096  Google Play services  com.google.android.gms    Tools     4.2
#
#          Rating Count         Installs  Minimum Installs  Maximum Installs  \
# 2155096    35128398.0  10,000,000,000+      1.000000e+10       12057627016
#
#          Free  Price  ...                                  Developer Website  \
# 2155096  True    0.0  ...  https://developers.google.com/android/google-p...
#
#               Developer Email      Released  Last Updated Content Rating  \
# 2155096  apps-help@google.com  May 24, 2012  Jun 10, 2021       Everyone
#
#                                  Privacy Policy Ad Supported In App Purchases  \
# 2155096  http://www.google.com/policies/privacy        False            False
#
#         Editors Choice         Scraped Time
# 2155096          False  2021-06-16 10:41:26
#
# [1 rows x 24 columns]

# %%
np.unique(str(apps['Size'].values))
# Out:
# array(["['10M' '2.9M' '3.7M' ... '29M' '10M' '5.2M']"], dtype='<U44')

# %%
np.unique(str(apps['Released'].values))
# Out:
# array(["['Feb 26, 2020' 'May 21, 2020' 'Aug 9, 2019' ... 'Aug 19, 2018'\n 'Aug 1, 2016' 'Aug 9, 2019']"],
#       dtype='<U93')

# %%
apps[(apps["In App Purchases"] == True)].shape
# Out:
# (195309, 24)

# %%
apps[(apps["Editors Choice"] == True)].shape
# Out:
# (853, 24)

# %% [markdown]
# ## <a id='31'>Проанализируем категории</a>
# И построим рейтинг популярности

# %%
#перечень категорий
np.unique(apps['Category'].values)
# Out:
# array(['Action', 'Adventure', 'Arcade', 'Art & Design', 'Auto & Vehicles',
#        'Beauty', 'Board', 'Books & Reference', 'Business', 'Card',
#        'Casino', 'Casual', 'Comics', 'Communication', 'Dating',
#        'Education', 'Educational', 'Entertainment', 'Events', 'Finance',
#        'Food & Drink', 'Health & Fitness', 'House & Home',
#        'Libraries & Demo', 'Lifestyle', 'Maps & Navigation', 'Medical',
#        'Music', 'Music & Audio', 'News & Magazines', 'Parenting',
#        'Personalization', 'Photography', 'Productivity', 'Puzzle',
#        'Racing', 'Role Playing', 'Shopping', 'Simulation', 'Social',
#        'Sports', 'Strategy', 'Tools', 'Travel & Local', 'Trivia',
#        'Video Players & Editors', 'Weather', 'Word'], dtype=object)

# %%
#посмотрим на количество приложений по категориям
pd.value_counts(apps['Category']).plot.bar();

# %%
# Количество приложений по категориям -10 самых крупных
apps['Category'].value_counts().head(10).plot.bar()

# %%
#проанализируем, какие значения можно взять для построения рейтинга. Берем оценку, её количество и количество скачиваний.
apps.describe()
# Out:
#              Rating  Rating Count  Minimum Installs  Maximum Installs  \
# count  2.290061e+06  2.290061e+06      2.312837e+06      2.312944e+06
# mean   2.203152e+00  2.864839e+03      1.834452e+05      3.202017e+05
# std    2.106223e+00  2.121626e+05      1.513144e+07      2.355495e+07
# min    0.000000e+00  0.000000e+00      0.000000e+00      0.000000e+00
# 25%    0.000000e+00  0.000000e+00      5.000000e+01      8.400000e+01
# 50%    2.900000e+00  6.000000e+00      5.000000e+02      6.950000e+02
# 75%    4.300000e+00  4.200000e+01      5.000000e+03      7.354000e+03
# max    5.000000e+00  1.385576e+08      1.000000e+10      1.205763e+10
#
#               Price
# count  2.312944e+06
# mean   1.034992e-01
# std    2.633127e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    4.000000e+02

# %%
#построим интерактивный выбор категорий
from ipywidgets import widgets, interactive

# %%
# Топ N самых популярных приложений в каждой категории по рейтингу
N=10
categories = set(apps["Category"])

category = widgets.Dropdown(
    options = categories,
    description = 'Category: ' 
)
#максимальные значения для нормализации
max_rating = apps["Rating"].max()
max_rating_count = apps["Rating Count"].max()
#max_minimum_installs = apps["Minimum Installs"].max()
max_maximum_installs = apps["Maximum Installs"].max()
#веса
w1, w2, w3 = 0.25, 0.25, 0.5

def get_custom_rating(row):
    return w1*row["Rating"]/max_rating + w2*row["Rating Count"]/max_rating_count + w3*row["Maximum Installs"]/max_maximum_installs
    
apps["Custom Rating"] = apps.apply(lambda row: get_custom_rating(row), axis=1)

def draw_plot(category):
    most_popular = apps[apps["Category"] == category].sort_values(by="Custom Rating", ascending=False).head(N)
    data = most_popular.plot.bar(x="App Name", y="Custom Rating", rot=90)
    plt.show()

interactive(draw_plot, category=category)
# Out:
# interactive(children=(Dropdown(description='Category: ', options=('Comics', 'Card', 'Productivity', 'Social', …

# %% [markdown]
# #### <a id='31'>Проанализируем стоимость приложений и категорий</a>
# Из гистограмм выше видим, что практически вся стоимость приложений указана в usd, но есть и другие валюты. Сделаем аализ более универсальным, переведем стоимость приложений в рубли

# %%
#установим пакет для курсов валют ЦБ
from pycbrf import ExchangeRates

# %%
#котировки валют
today = date.today().strftime("%Y-%m-%d")
print(f"Загружаем котировки валют за сегодня: {today}")
rates = ExchangeRates(today, locale_en=True)
# Out:
# Загружаем котировки валют за сегодня: 2021-07-15

# %%
#Проверим какие валюты можем перевести
currencies = set(apps["Currency"])
print(f"Всего {len(currencies)} валют")
print(currencies)
for currency in currencies:
    if(currency != 'XXX' and not pd.isna(currency)):
        rate = rates[currency]
        if(rate is not None):
            print(f"{currency}: {rates[currency].rate}")
        else:
            print(f"Валюта {currency} не определена")
# Out:
# Всего 16 валют
# {nan, 'EUR', 'SGD', 'XXX', 'TRY', 'USD', 'INR', 'CAD', 'GBP', 'BRL', 'KRW', 'ZAR', 'RUB', 'VND', 'AUD', 'PKR'}
# EUR: 87.3917
# SGD: 54.6997
# TRY: 8.59713
# USD: 74.1236
# INR: 0.993714
# CAD: 59.2704
# GBP: 102.6982
# BRL: 14.3545
# KRW: 0.0644867
# ZAR: 5.02768
# Валюта RUB не определена
# Валюта VND не определена
# AUD: 55.2147
# Валюта PKR не определена

# %%
#  PKR - пакистанская рупия, VND - вьетнамский донг, определим вручную...RUB и так рубль )

# %%
# Добавим колонку price_rub цена в рублях
handle_dict = {'PKR': 0.47, 'VND': 0.0032}
def get_price_rub(price, currency):
    total_rub = None
    if(currency != 'XXX' and not pd.isna(currency)):
        rate = rates[currency]
        if(rate is not None):
            total_rub = price * float(rate.rate)
        if(currency in handle_dict):
            total_rub = price * handle_dict[currency]
        if( currency == 'RUB'):
            total_rub = price
    return total_rub

# %%
apps["Price_rub"] = apps.apply(lambda row: get_price_rub(row["Price"], row["Currency"]), axis=1)
apps_not_free = apps[(apps["Free"] == False)]
apps_not_free.head(10)
# Out:
#                             App Name  \
# 273                  Limitless Paint
# 296    Standalone Golf GPS by Hole19
# 417    Calculator + Widget 21 themes
# 554                  莎士比亞11連環錯（英漢對照）
# 618             Theme Park Simulator
# 637            Bukuu - Akibat Menipu
# 661                JOTNA MEDIA GROUP
# 775  Web Development PRO (HTML, CSS)
# 786                    K8 CODE PRIME
# 796               Kila: The Lazy Pig
#
#                                                App Id           Category  \
# 273                   com.bytescaffold.limitlesspaint              Tools
# 296                               com.hole19golf.wear             Sports
# 417                     makatea.pro.calculator.widget              Tools
# 554                tw.com.mebook.generic4719180217042          Education
# 618  com.bestridesimulators.theme.park.simulator.game         Simulation
# 637            bukuu.com.my.siri.haiwan.akibat.menipu          Education
# 661                          com.app.jotnamediagroupi           Business
# 775                  com.technoapps.webdevelopmentpro          Education
# 786             appinventor.ai_mc207742.K8_CODE_PRIME              Tools
# 796                                   kila.thelazypig  Books & Reference
#
#      Rating  Rating Count Installs  Minimum Installs  Maximum Installs   Free  \
# 273     4.5         236.0  10,000+           10000.0             34125  False
# 296     2.8         160.0  10,000+           10000.0             10407  False
# 417     3.5         468.0  10,000+           10000.0             12019  False
# 554     0.0           0.0       1+               1.0                 2  False
# 618     3.8        1158.0  10,000+           10000.0             23644  False
# 637     0.0           0.0       1+               1.0                 2  False
# 661     4.9          19.0     100+             100.0               487  False
# 775     4.5          79.0   5,000+            5000.0              7391  False
# 786     0.0           0.0      10+              10.0                38  False
# 796     0.0           0.0       1+               1.0                 2  False
#
#      Price  ...      Released  Last Updated Content Rating  \
# 273   1.99  ...  Nov 30, 2018  Apr 08, 2019       Everyone
# 296   4.99  ...   Feb 7, 2017  Dec 22, 2020       Everyone
# 417   0.99  ...   Oct 4, 2012  Feb 09, 2014       Everyone
# 554   2.99  ...  Mar 15, 2017  Mar 15, 2017       Everyone
# 618   0.99  ...   Nov 3, 2020  Feb 05, 2021       Everyone
# 637   1.99  ...  Jan 12, 2016  Jan 13, 2016       Everyone
# 661   4.99  ...  Jun 15, 2020  Jun 15, 2020       Everyone
# 775   3.49  ...  Dec 14, 2019  Dec 14, 2019       Everyone
# 786  24.99  ...   Aug 8, 2019  Aug 09, 2019       Everyone
# 796   0.99  ...  Aug 10, 2020  Aug 10, 2020       Everyone
#
#                                         Privacy Policy Ad Supported  \
# 273  http://htmlpreview.github.io/?https://github.c...        False
# 296    https://www.hole19golf.com/terms/#PrivacyPolicy        False
# 417                                                NaN        False
# 554  http://mobile.mebook-buy.com/android/privacy.html        False
# 618  https://bestridesimulators.com/lunaria-games-s-l/         True
# 637  https://www.mmsc.com.my/bukuu/terma-penggunaan...        False
# 661  https://appcdn.media/privacy/?app=JOTNA%20MEDI...         True
# 775  https://technoapps92.blogspot.com/p/blog-page_...        False
# 786                                                NaN        False
# 796                    http://www.kilafun.com/privacy/        False
#
#     In App Purchases Editors Choice         Scraped Time Custom Rating  \
# 273            False          False  2021-06-15 20:19:52  2.250018e-01
# 296            False          False  2021-06-15 20:19:53  1.400007e-01
# 417            False          False  2021-06-15 20:20:00  1.750013e-01
# 554            False          False  2021-06-15 20:20:07  8.293506e-11
# 618             True          False  2021-06-15 20:20:11  1.900031e-01
# 637            False          False  2021-06-15 20:20:13  8.293506e-11
# 661            False          False  2021-06-15 20:20:14  2.450001e-01
# 775            False          False  2021-06-15 20:20:20  2.250004e-01
# 786            False          False  2021-06-15 20:20:20  1.575766e-09
# 796            False          False  2021-06-15 20:20:21  8.293506e-11
#
#        Price_rub
# 273   147.505964
# 296   369.876764
# 417    73.382364
# 554   221.629564
# 618    73.382364
# 637   147.505964
# 661   369.876764
# 775   258.691364
# 786  1852.348764
# 796    73.382364
#
# [10 rows x 26 columns]

# %%
apps_not_free.shape
# Out:
# (45068, 26)

# %% [markdown]
# #### Найдем ТОП самых дорогих приложений и категорий

# %%
#Топ N самых дорогих приложений
N = 30
most_expensive = apps_not_free[["Category","App Name", "Price", "Currency", "Price_rub"]].sort_values(by="Price_rub", ascending=False).head(N)
most_expensive
# Out:
#                   Category                                        App Name  \
# 544468        Productivity                                    MESH Connect
# 817106              Casual                          Most Expensive Clicker
# 1602171           Business                     I'm Rich - VIP Club Limited
# 20127                Tools                                        TEST EGY
# 1444845             Puzzle                      Plasma duct - Premium Game
# 921941       Entertainment                                         Luxsure
# 1399820              Board                        Most expensive word game
# 1698479       Productivity                           Report Form Pro Nitro
# 1580432             Arcade                                 Baby Nightmares
# 1327436             Social                Youmeunit PRO — ver.4U4M34353RY1
# 1913716             Dating                                Nu Media TV Live
# 1859780      Music & Audio                                            AudD
# 1539189          Lifestyle                                         Why Not
# 1638663  Maps & Navigation                                  Точки интереса
# 1842192              Tools                                        My Money
# 1312551      Entertainment                                         Success
# 789532    Health & Fitness                           Acid Reflux Treatment
# 652320   Books & Reference                                  secret of life
# 2085590      Entertainment                    Series Addict Pro - TV Guide
# 268776            Business                                           Taxes
# 644212              Arcade               Challenge Impossible Ball for you
# 284676               Tools       Accounting Provider for Green Office Flow
# 1280247             Social                                        RichWall
# 829385            Shopping  Premium Luxury Watches - Luxury Watches Brands
# 1821265              Tools                 Auto File Transfer (deprecated)
# 1492654          Lifestyle                                  I am very RICH
# 776953           Lifestyle                                       Happiness
# 1436711              Tools                 VPN Tornado Pro - Paid Vpn 2021
# 1577807              Tools                              JAVAD Mobile Tools
# 1605685               Word                       Most Expensive Wordsearch
#
#           Price Currency     Price_rub
# 544468   400.00      USD  29649.440000
# 817106   399.99      USD  29648.698764
# 1602171  399.99      USD  29648.698764
# 20127    399.99      USD  29648.698764
# 1444845  399.99      USD  29648.698764
# 921941   399.99      USD  29648.698764
# 1399820  399.99      USD  29648.698764
# 1698479  399.99      USD  29648.698764
# 1580432  399.99      USD  29648.698764
# 1327436  399.99      USD  29648.698764
# 1913716  399.99      USD  29648.698764
# 1859780  399.99      USD  29648.698764
# 1539189  399.99      USD  29648.698764
# 1638663  399.99      USD  29648.698764
# 1842192  399.99      USD  29648.698764
# 1312551  399.99      USD  29648.698764
# 789532   399.99      USD  29648.698764
# 652320   399.99      USD  29648.698764
# 2085590  399.99      USD  29648.698764
# 268776   399.99      USD  29648.698764
# 644212   399.99      USD  29648.698764
# 284676   399.99      USD  29648.698764
# 1280247  399.99      USD  29648.698764
# 829385   399.99      USD  29648.698764
# 1821265  394.99      USD  29278.080764
# 1492654  394.99      USD  29278.080764
# 776953   389.99      USD  28907.462764
# 1436711  389.99      USD  28907.462764
# 1577807  389.99      USD  28907.462764
# 1605685  384.99      USD  28536.844764

# %%
# Топ N cамые дорогие категории (мера - среднее значение цены в категории)
N = 20
apps_not_free.groupby(['Category']).Price_rub.agg(['mean']).sort_values(by="mean", ascending=False).head(N)
# Out:
#                                 mean
# Category
# Dating                   1710.278531
# Medical                  1237.780131
# Business                  911.405656
# Art & Design              707.384786
# Sports                    590.011184
# Social                    588.716585
# Auto & Vehicles           560.887035
# Food & Drink              541.369680
# Shopping                  515.382606
# Arcade                    502.615059
# Lifestyle                 496.343459
# Books & Reference         464.786577
# Maps & Navigation         457.822588
# Productivity              454.413455
# Finance                   450.931066
# Education                 445.577656
# Health & Fitness          433.271926
# Tools                     384.046047
# Entertainment             377.088765
# Video Players & Editors   371.273985

# %%
#второй вариант- категории, которые содержат наибольшее количество платных приложений 
apps_expensive = apps_not_free[["Category","App Name", "Price", "Currency", "Price_rub"]].sort_values(by="Price_rub", ascending=False)
apps_expensive['Category'].value_counts().head(10).plot.bar()

# %% [markdown]
# #### Найдем ТОП   категорий с приложениями  без отзывов

# %%
apps_without_feedback = apps[apps["Rating Count"] == 0]

# %%
# Топ категорий, содержащих самое большое количество приложений без отзывов (Rating Count = 0)
apps_without_feedback['Category'].value_counts()
# Out:
# Education                  111528
# Business                    91652
# Music & Audio               74406
# Lifestyle                   62539
# Tools                       56922
# Entertainment               54003
# Food & Drink                50555
# Books & Reference           49454
# Health & Fitness            49216
# Shopping                    41939
# Productivity                40487
# Travel & Local              34923
# Personalization             31201
# Finance                     25711
# Communication               22890
# Arcade                      22392
# Casual                      20288
# Sports                      20259
# Social                      18801
# Puzzle                      18330
# Medical                     17255
# News & Magazines            17078
# Photography                 12541
# Maps & Navigation           11313
# Art & Design                 9368
# Events                       8916
# Action                       8714
# Educational                  8648
# House & Home                 8631
# Auto & Vehicles              8493
# Beauty                       7566
# Adventure                    7054
# Trivia                       4485
# Simulation                   3594
# Video Players & Editors      3332
# Board                        3301
# Word                         2666
# Racing                       2639
# Libraries & Demo             2474
# Dating                       2319
# Strategy                     2271
# Card                         1884
# Weather                      1703
# Parenting                    1496
# Role Playing                 1418
# Music                        1311
# Casino                       1032
# Comics                        764
# Name: Category, dtype: int64

# %%
apps_without_feedback['Category'].value_counts().head(20).plot.bar()
